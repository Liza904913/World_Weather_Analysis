# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)
gmaps.configure(api_key="AIzaSyCU7St9Tw_leo119DCn1FTxwT4qBYioEJc")

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("weather_data/hotels.csv")
vacation_df.head(30)
# Out:
#     Hotel Name            City Country  Max Temp      Lat       Lng  \
# 0            0            Poum      NC     72.61 -20.2333  164.0167
# 1            8         Yabassi      CM     74.84   4.4570    9.9682
# 2            9            Naze      JP     77.40  28.3667  129.4833
# 3           13      Oranjestad      AW     87.75  12.5240  -70.0270
# 4           14        Hamilton      US     71.04  39.1834  -84.5333
# 5           17         Rikitea      PF     73.90 -23.1203 -134.9692
# 6           21          Canyon      US     91.47  34.9803 -101.9188
# 7           22          Semnan      IR     74.19  35.5729   53.3971
# 8           23         Chanute      US     81.91  37.6792  -95.4572
# 9           25      Cumberland      US     80.08  35.0502  -78.8664
# 10          31        Katsuura      JP     70.20  35.1333  140.3000
# 11          34       Abu Dhabi      AE     91.42  24.4667   54.3667
# 12          35         Kahului      US     87.82  20.8947 -156.4700
# 13          37            Auki      SB     84.00  -8.7676  160.7034
# 14          39          Atuona      PF     78.30  -9.8000 -139.0333
# 15          40          Lompoc      US     86.02  34.6391 -120.4579
# 16          42           Vaini      TO     71.76 -21.2000 -175.2000
# 17          44          Albany      US     72.43  42.6001  -73.9662
# 18          45         Lizzano      IT     70.68  40.3910   17.4476
# 19          51  Fereydun Kenar      IR     73.89  36.6864   52.5225
# 20          53            Liku      ID     75.76  -0.7275  119.8922
# 21          59    Puerto Ayora      EC     75.16  -0.7393  -90.3518
# 22          63      Burlington      US     76.82  39.8835  -74.6413
# 23          65          Yarada      IN     79.12  17.6500   83.2667
# 24          67           Arlit      NE     91.13  18.7369    7.3853
# 25          68         Isangel      VU     75.31 -19.5500  169.2667
# 26          69        Victoria      HK     84.38  22.2855  114.1577
# 27          70           Basco      PH     84.29  20.4487  121.9702
# 28          72       Mogadishu      SO     77.72   2.0371   45.3438
# 29          73          Portel      BR     79.95  -1.9356  -50.8211
#
#                                          Hotel Name.1
# 0                                         Gîte kajeon
# 1                                          MOTEL FOMI
# 2                                         オーベルジュ・アガルイ
# 3                    Divi Village Golf & Beach Resort
# 4                           Six Acres Bed & Breakfast
# 5                                     People ThankYou
# 6   Holiday Inn Express & Suites Canyon, an IHG Hotel
# 7                                Semnan Tourist Hotel
# 8                           Guest House Motel Chanute
# 9                                  American Eagle Inn
# 10                            Katsuura Hotel Mikazuki
# 11                      Ramee Garden Hotel Apartments
# 12                                 Maui Seaside Hotel
# 13                                         Auki Motel
# 14                                        Villa Enata
# 15           Holiday Inn Express Lompoc, an IHG Hotel
# 16                                Keleti Beach Resort
# 17                                                NaN
# 18                   La Nuova Fattoria - Lizzano (TA)
# 19                         Khezer Shahr Tourist Hotel
# 20                                              Wahyu
# 21                          Finch Bay Galapagos Hotel
# 22                                       Delanco Camp
# 23                                             Jeevan
# 24                   Case de Passage De la Prefecture
# 25                                        Tanna Lodge
# 26                                 Mini Hotel Central
# 27                                  Nathaniel's Lodge
# 28                                         Hotel Juba
# 29                                   Kitnet do Marcos

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Name</dt><dd>{column1}</dd>
<dt>Another name</dt><dd>{column2}</dd>
</dl>
"""

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]
print(hotel_info)
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>0</dd>\n<dt>City</dt><dd>Poum</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Max Temp</dt><dd>72.61 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>8</dd>\n<dt>City</dt><dd>Yabassi</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Max Temp</dt><dd>74.84 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>9</dd>\n<dt>City</dt><dd>Naze</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Max Temp</dt><dd>77.4 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>13</dd>\n<dt>City</dt><dd>Oranjestad</dd>\n<dt>Country</dt><dd>AW</dd>\n<dt>Max Temp</dt><dd>87.75 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>14</dd>\n<dt>City</dt><dd>Hamilton</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>71.04 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>17</dd>\n<dt>City</dt><dd>Rikitea</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>73.9 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>21</dd>\n<dt>City</dt><dd>Canyon</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>91.47 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>22</dd>\n<dt>City</dt><dd>Semnan</dd>\n<dt>Country</dt><dd>IR</dd>\n<dt>Max Temp</dt><dd>74.19 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>23</dd>\n<dt>City</dt><dd>Chanute</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>81.91 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>25</dd>\n<dt>City</dt><dd>Cumberland</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>80.08 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>31</dd>\n<dt>City</dt><dd>Katsuura</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Max Temp</dt><dd>70.2 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>34</dd>\n<dt>City</dt><dd>Abu Dhabi</dd>\n<dt>Country</dt><dd>AE</dd>\n<dt>Max Temp</dt><dd>91.42 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>35</dd>\n<dt>City</dt><dd>Kahului</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>87.82 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>37</dd>\n<dt>City</dt><dd>Auki</dd>\n<dt>Country</dt><dd>SB</dd>\n<dt>Max Temp</dt><dd>84.0 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>39</dd>\n<dt>City</dt><dd>Atuona</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Max Temp</dt><dd>78.3 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>40</dd>\n<dt>City</dt><dd>Lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>86.02 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>42</dd>\n<dt>City</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Max Temp</dt><dd>71.76 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>44</dd>\n<dt>City</dt><dd>Albany</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>72.43 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>45</dd>\n<dt>City</dt><dd>Lizzano</dd>\n<dt>Country</dt><dd>IT</dd>\n<dt>Max Temp</dt><dd>70.68 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>51</dd>\n<dt>City</dt><dd>Fereydun Kenar</dd>\n<dt>Country</dt><dd>IR</dd>\n<dt>Max Temp</dt><dd>73.89 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>53</dd>\n<dt>City</dt><dd>Liku</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Max Temp</dt><dd>75.76 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>59</dd>\n<dt>City</dt><dd>Puerto Ayora</dd>\n<dt>Country</dt><dd>EC</dd>\n<dt>Max Temp</dt><dd>75.16 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>63</dd>\n<dt>City</dt><dd>Burlington</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>76.82 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>65</dd>\n<dt>City</dt><dd>Yarada</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Max Temp</dt><dd>79.12 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>67</dd>\n<dt>City</dt><dd>Arlit</dd>\n<dt>Country</dt><dd>NE</dd>\n<dt>Max Temp</dt><dd>91.13 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>68</dd>\n<dt>City</dt><dd>Isangel</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Max Temp</dt><dd>75.31 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>69</dd>\n<dt>City</dt><dd>Victoria</dd>\n<dt>Country</dt><dd>HK</dd>\n<dt>Max Temp</dt><dd>84.38 °F</dd>\n</dl>\n', '\n<dl>\n<dt>Hotel Name</dt><dd>70 ...

# %%
# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]
locations
# Out:
#          Lat       Lng
# 0   -20.2333  164.0167
# 1     4.4570    9.9682
# 2    28.3667  129.4833
# 3    12.5240  -70.0270
# 4    39.1834  -84.5333
# ..       ...       ...
# 275   7.7102   81.6924
# 276  19.2833  -81.2500
# 277  46.8267 -100.8896
# 278 -23.7869  -54.2836
# 279  30.3658  -88.5561
#
# [280 rows x 2 columns]

# %%
# 4a. Add a marker layer for each city to the map.
# 4b. Display the figure
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df["City"] == "Hamilton")]
vacation_end = vacation_df.loc[(vacation_df["City"] == "Hamilton")]
vacation_stop1  = vacation_df.loc[(vacation_df["City"] == "Chanute")]
vacation_stop2 = vacation_df.loc[(vacation_df["City"] == "Canyon")]
vacation_stop3 = vacation_df.loc[(vacation_df["City"] == "Lompoc")]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0]
print(f'Start: {start}, End: {end}')

stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]
print(f'Stop 1: {stop1}, Stop 2: {stop2}, Stop 3: {stop3}')

fig = gmaps.figure()


city_itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')

fig.add_layer(city_itinerary)
fig
# Out:
# Start: (39.1834, -84.5333), End: (39.1834, -84.5333)
# Stop 1: (37.6792, -95.4572), Stop 2: (34.9803, -101.9188), Stop 3: (34.6391, -120.4579)
# Figure(layout=FigureLayout(height='420px'))

# %%
vacation_start
# Out:
#    Hotel Name      City Country  Max Temp      Lat      Lng  \
# 4          14  Hamilton      US     71.04  39.1834 -84.5333
#
#                 Hotel Name.1
# 4  Six Acres Bed & Breakfast

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2,vacation_stop3], ignore_index=True)
itinerary_df
#['end'],['stop1'],['stop2'],['stop3'],
# Out:
#    Hotel Name      City Country  Max Temp      Lat       Lng  \
# 0          14  Hamilton      US     71.04  39.1834  -84.5333
# 1          23   Chanute      US     81.91  37.6792  -95.4572
# 2          21    Canyon      US     91.47  34.9803 -101.9188
# 3          40    Lompoc      US     86.02  34.6391 -120.4579
#
#                                         Hotel Name.1
# 0                          Six Acres Bed & Breakfast
# 1                          Guest House Motel Chanute
# 2  Holiday Inn Express & Suites Canyon, an IHG Hotel
# 3           Holiday Inn Express Lompoc, an IHG Hotel

# %%
itinerary_df.rename(columns= {"Hotel Name" : "Hotel ID", "Hotel Name.1" : "Hotel Name"},inplace=True)

# %%
itinerary_df
# Out:
#    Hotel ID      City Country  Max Temp      Lat       Lng  \
# 0        14  Hamilton      US     71.04  39.1834  -84.5333
# 1        23   Chanute      US     81.91  37.6792  -95.4572
# 2        21    Canyon      US     91.47  34.9803 -101.9188
# 3        40    Lompoc      US     86.02  34.6391 -120.4579
#
#                                           Hotel Name
# 0                          Six Acres Bed & Breakfast
# 1                          Guest House Motel Chanute
# 2  Holiday Inn Express & Suites Canyon, an IHG Hotel
# 3           Holiday Inn Express Lompoc, an IHG Hotel

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# %%
# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.

# 11b. Display the figure

# %%
gmaps.marker_layer(
    locations, 
    hover_text='', 
    label='', 
    info_box_content=None, 
    display_info_box=None
)

# %%
markers = gmaps.marker_layer(
    locations,
    hover_text=hotel_info
#    info_box_content= hotel_info
)

# Add the layer to the map
fig.add_layer(markers)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
hotel_info
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>Six Acres Bed & Breakfast</dd>\n<dt>City</dt><dd>Hamilton</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>71.04 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Guest House Motel Chanute</dd>\n<dt>City</dt><dd>Chanute</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>81.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express & Suites Canyon, an IHG Hotel</dd>\n<dt>City</dt><dd>Canyon</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>91.47 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express Lompoc, an IHG Hotel</dd>\n<dt>City</dt><dd>Lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Max Temp</dt><dd>86.02 °F</dd>\n</dl>\n']
